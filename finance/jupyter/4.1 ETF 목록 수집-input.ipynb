# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/finance-data-analysis/blob/main/4.1%20ETF%20%EB%AA%A9%EB%A1%9D%20%EC%88%98%EC%A7%91-input.ipynb)
#
#
# ## ETF란?
# * ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF)이 투명하게 공개되어 있고, 장중에는 실시간으로 순자산가치(NAV)가 제공되어 거래에 참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
#     * 출처 : [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)
#
#
# ## 크롬 브라우저의 네트워크 정보를 통한 데이터 수집
# * json 데이터 수집과 파일저장 방법
#
# * [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)

# %%
# 라이브러리를 불러옵니다.
# 데이터 분석을 위한 pandas, 수치계산을 위한 numpy, http 요청을 위한 requests를 받아옵니다.
import pandas as pd
import numpy as np
import requests

# %%
# 수집할 url을 가져옵니다.
url = "https://finance.naver.com/sise/etf.nhn"
url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc&_callback=window.__jindo2_callback._8345"
url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc"
url
# Out:
# 'https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc'

# %% [markdown]
# ## Pandas를 통한 요청

# %%
pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:980, in HTTPConnection.send(self, data)
#     979 if self.auto_open:
# --> 980     self.connect()
#     981 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1454, in HTTPSConnection.connect(self)
#    1452     server_hostname = self.host
# -> 1454 self.sock = self._context.wrap_socket(self.sock,
#    1455                                       server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /Users/musetea/Desktop/2022/python/finance/jupyter/4.1 ETF 목록 수집-input.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/musetea/Desktop/2022/python/finance/jupyter/4.1%20ETF%20%EB%AA%A9%EB%A1%9D%20%EC%88%98%EC%A7%91-input.ipynb#ch0000004?line=0'>1</a> pd.read_html(url)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/html.py:919, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     916 p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918 try:
# --> 919     tables = p.parse_tables()
#     920 except ValueError as caught:
#     921     # if `io` is an io-like object, check if it's seekable
#     922     # and try to rewind it before trying the next parser
#     923     if hasattr(io, "seekable") and io.seekable():
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/html.py:239, in _HtmlFrameParser.parse_tables(self)
#     231 def parse_tables(self):
#     232     """
#     233     Parse and return all tables from the DOM.
#     234
#    (...)
#     237     list of parsed (header, body, footer) tuples from tables.
#     238     """
# --> 239     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     240     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/html.py:758, in _LxmlFrameParser._build_doc(self)
#     756             pass
#     757     else:
# --> 758         raise e
#     759 else:
#     760     if not hasattr(r, "text_content"):
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/html.py:739, in _LxmlFrameParser._build_doc(self)
#     737 try:
#     738     if is_url(self.io):
# --> 739         with urlopen(self.io) as f:
#     740             r = parse(f, parser=parser)
#     741     else:
#     742         # try to parse the input in the simplest way
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/common.py:239, in urlopen(*args, **kwargs)
#     233 """
#     234 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     235 the stdlib.
#     236 """
#     237 import urllib.request
# --> 239 return urllib.request.urlopen(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:1349, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346         h.request(req.get_method(), req.selector, req.data, headers,
#    1347                   encode_chunked=req.has_header('Transfer-encoding'))
#    1348     except OSError as err: # timeout error
# -> 1349         raise URLError(err)
#    1350     r = h.getresponse()
#    1351 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)>

# %% [markdown]
# ## JSON
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/JSON_vector_logo.svg/300px-JSON_vector_logo.svg.png" width="100">
#
# JSON(제이슨, JavaScript Object Notation)은 속성-값 쌍( attribute–value pairs and array data types (or any other serializable value)) 또는 "키-값 쌍"으로 이루어진 데이터 오브젝트를 전달하기 위해 인간이 읽을 수 있는 텍스트를 사용하는 개방형 표준 포맷이다. 비동기 브라우저/서버 통신 (AJAX)을 위해, 넓게는 XML(AJAX가 사용)을 대체하는 주요 데이터 포맷이다. 특히, 인터넷에서 자료를 주고 받을 때 그 자료를 표현하는 방법으로 알려져 있다. 자료의 종류에 큰 제한은 없으며, 특히 컴퓨터 프로그램의 변수값을 표현하는 데 적합하다.
# 본래는 자바스크립트 언어로부터 파생되어 자바스크립트의 구문 형식을 따르지만 언어 독립형 데이터 포맷이다. 즉, 프로그래밍 언어나 플랫폼에 독립적이므로, 구문 분석 및 JSON 데이터 생성을 위한 코드는 C, C++, C#, 자바, 자바스크립트, 펄, 파이썬 등 수많은 프로그래밍 언어에서 쉽게 이용할 수 있다.
#
# * 출처 : [JSON - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/JSON)

# %% [markdown]
# ## requests를 통한 HTTP 요청
# * [Requests: HTTP for Humans™ — Requests documentation](https://requests.readthedocs.io/en/master/)

# %%
# requests 라이브러리를 통해 url을 받아옵니다.
response = requests.get(url)
response.raise_for_status()

# %%
etf_json = response.json()
etf_json["result"]
# Out:
# {'etfItemList': [{'itemcode': '069500',
#    'etfTabCode': 1,
#    'itemname': 'KODEX 200',
#    'nowVal': 30775,
#    'risefall': '5',
#    'changeVal': -115,
#    'changeRate': -0.37,
#    'nav': 30761.0,
#    'threeMonthEarnRate': -14.4298,
#    'quant': 8520894,
#    'amonut': 262842,
#    'marketSum': 47455},
#   {'itemcode': '371460',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 차이나전기차SOLACTIVE',
#    'nowVal': 17510,
#    'risefall': '2',
#    'changeVal': 510,
#    'changeRate': 3.0,
#    'nav': 17554.0,
#    'threeMonthEarnRate': 12.6573,
#    'quant': 11623919,
#    'amonut': 201763,
#    'marketSum': 41933},
#   {'itemcode': '122630',
#    'etfTabCode': 3,
#    'itemname': 'KODEX 레버리지',
#    'nowVal': 14255,
#    'risefall': '5',
#    'changeVal': -65,
#    'changeRate': -0.45,
#    'nav': 14282.0,
#    'threeMonthEarnRate': -28.0583,
#    'quant': 53123036,
#    'amonut': 760029,
#    'marketSum': 22095},
#   {'itemcode': '133690',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국나스닥100',
#    'nowVal': 67165,
#    'risefall': '2',
#    'changeVal': 1065,
#    'changeRate': 1.61,
#    'nav': 67140.0,
#    'threeMonthEarnRate': -15.3487,
#    'quant': 109913,
#    'amonut': 7357,
#    'marketSum': 19961},
#   {'itemcode': '252670',
#    'etfTabCode': 3,
#    'itemname': 'KODEX 200선물인버스2X',
#    'nowVal': 3360,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.45,
#    'nav': 3360.0,
#    'threeMonthEarnRate': 34.3373,
#    'quant': 364059617,
#    'amonut': 1216157,
#    'marketSum': 19632},
#   {'itemcode': '214980',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 단기채권PLUS',
#    'nowVal': 103765,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.02,
#    'nav': 103770.0,
#    'threeMonthEarnRate': -0.0241,
#    'quant': 450348,
#    'amonut': 46732,
#    'marketSum': 18986},
#   {'itemcode': '102110',
#    'etfTabCode': 1,
#    'itemname': 'TIGER 200',
#    'nowVal': 30835,
#    'risefall': '5',
#    'changeVal': -110,
#    'changeRate': -0.36,
#    'nav': 30820.0,
#    'threeMonthEarnRate': -14.4244,
#    'quant': 2379512,
#    'amonut': 73542,
#    'marketSum': 18547},
#   {'itemcode': '157450',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 단기통안채',
#    'nowVal': 100945,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.01,
#    'nav': 100939.0,
#    'threeMonthEarnRate': 0.2134,
#    'quant': 3550,
#    'amonut': 358,
#    'marketSum': 18298},
#   {'itemcode': '360750',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국S&P500',
#    'nowVal': 12305,
#    'risefall': '2',
#    'changeVal': 175,
#    'changeRate': 1.44,
#    'nav': 12310.0,
#    'threeMonthEarnRate': -10.9333,
#    'quant': 2000351,
#    'amonut': 24539,
#    'marketSum': 16335},
#   {'itemcode': '153130',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 단기채권',
#    'nowVal': 103405,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.0,
#    'nav': 103414.0,
#    'threeMonthEarnRate': 0.058,
#    'quant': 5034338,
#    'amonut': 520655,
#    'marketSum': 14516},
#   {'itemcode': '292150',
#    'etfTabCode': 2,
#    'itemname': 'TIGER TOP10',
#    'nowVal': 10025,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 10015.0,
#    'threeMonthEarnRate': -16.263,
#    'quant': 303265,
#    'amonut': 3035,
#    'marketSum': 13865},
#   {'itemcode': '273130',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 종합채권(AA-이상)액티브',
#    'nowVal': 101140,
#    'risefall': '2',
#    'changeVal': 420,
#    'changeRate': 0.42,
#    'nav': 101114.0,
#    'threeMonthEarnRate': -4.9049,
#    'quant': 1421,
#    'amonut': 143,
#    'marketSum': 13701},
#   {'itemcode': '381180',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국필라델피아반도체나스닥',
#    'nowVal': 9165,
#    'risefall': '2',
#    'changeVal': 95,
#    'changeRate': 1.05,
#    'nav': 9171.0,
#    'threeMonthEarnRate': -18.9238,
#    'quant': 950734,
#    'amonut': 8683,
#    'marketSum': 12808},
#   {'itemcode': '102780',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 삼성그룹',
#    'nowVal': 8135,
#    'risefall': '5',
#    'changeVal': -40,
#    'changeRate': -0.49,
#    'nav': 8144.0,
#    'threeMonthEarnRate': -6.6888,
#    'quant': 512965,
#    'amonut': 4184,
#    'marketSum': 12796},
#   {'itemcode': '381170',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국테크TOP10 INDXX',
#    'nowVal': 9895,
#    'risefall': '2',
#    'changeVal': 180,
#    'changeRate': 1.85,
#    'nav': 9899.0,
#    'threeMonthEarnRate': -18.0515,
#    'quant': 524371,
#    'amonut': 5168,
#    'marketSum': 12765},
#   {'itemcode': '305720',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 2차전지산업',
#    'nowVal': 18060,
#    'risefall': '5',
#    'changeVal': -720,
#    'changeRate': -3.83,
#    'nav': 18082.0,
#    'threeMonthEarnRate': 4.5016,
#    'quant': 4309888,
#    'amonut': 79375,
#    'marketSum': 12191},
#   {'itemcode': '305540',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 2차전지테마',
#    'nowVal': 18490,
#    'risefall': '5',
#    'changeVal': -850,
#    'changeRate': -4.4,
#    'nav': 18490.0,
#    'threeMonthEarnRate': 3.917,
#    'quant': 3708560,
#    'amonut': 69878,
#    'marketSum': 11806},
#   {'itemcode': '310970',
#    'etfTabCode': 1,
#    'itemname': 'TIGER MSCI Korea TR',
#    'nowVal': 12550,
#    'risefall': '5',
#    'changeVal': -65,
#    'changeRate': -0.52,
#    'nav': 12557.0,
#    'threeMonthEarnRate': -14.1253,
#    'quant': 5221,
#    'amonut': 65,
#    'marketSum': 11609},
#   {'itemcode': '278530',
#    'etfTabCode': 1,
#    'itemname': 'KODEX 200TR',
#    'nowVal': 10255,
#    'risefall': '5',
#    'changeVal': -40,
#    'changeRate': -0.39,
#    'nav': 10249.0,
#    'threeMonthEarnRate': -14.3511,
#    'quant': 90503,
#    'amonut': 931,
#    'marketSum': 10675},
#   {'itemcode': '423160',
#    'etfTabCode': 7,
#    'itemname': 'KODEX KOFR금리액티브(합성)',
#    'nowVal': 100260,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.0,
#    'nav': 100257.0,
#    'threeMonthEarnRate': None,
#    'quant': 1366,
#    'amonut': 136,
#    'marketSum': 10222},
#   {'itemcode': '148020',
#    'etfTabCode': 1,
#    'itemname': 'KBSTAR 200',
#    'nowVal': 30895,
#    'risefall': '5',
#    'changeVal': -40,
#    'changeRate': -0.13,
#    'nav': 30872.0,
#    'threeMonthEarnRate': -14.8383,
#    'quant': 675289,
#    'amonut': 20877,
#    'marketSum': 10180},
#   {'itemcode': '114800',
#    'etfTabCode': 3,
#    'itemname': 'KODEX 인버스',
#    'nowVal': 5040,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.3,
#    'nav': 5044.0,
#    'threeMonthEarnRate': 16.3194,
#    'quant': 56739745,
#    'amonut': 285002,
#    'marketSum': 8805},
#   {'itemcode': '233740',
#    'etfTabCode': 3,
#    'itemname': 'KODEX 코스닥150레버리지',
#    'nowVal': 7565,
#    'risefall': '5',
#    'changeVal': -415,
#    'changeRate': -5.2,
#    'nav': 7631.0,
#    'threeMonthEarnRate': -33.1939,
#    'quant': 43629502,
#    'amonut': 342422,
#    'marketSum': 8231},
#   {'itemcode': '394670',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#    'nowVal': 10710,
#    'risefall': '2',
#    'changeVal': 140,
#    'changeRate': 1.32,
#    'nav': 10764.0,
#    'threeMonthEarnRate': 3.831,
#    'quant': 316195,
#    'amonut': 3363,
#    'marketSum': 7099},
#   {'itemcode': '139260',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 200 IT',
#    'nowVal': 26905,
#    'risefall': '5',
#    'changeVal': -150,
#    'changeRate': -0.55,
#    'nav': 26922.0,
#    'threeMonthEarnRate': -17.9729,
#    'quant': 304667,
#    'amonut': 8228,
#    'marketSum': 6990},
#   {'itemcode': '091180',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 자동차',
#    'nowVal': 16815,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 16819.0,
#    'threeMonthEarnRate': -3.9802,
#    'quant': 549923,
#    'amonut': 9271,
#    'marketSum': 6381},
#   {'itemcode': '278540',
#    'etfTabCode': 1,
#    'itemname': 'KODEX MSCI Korea TR',
#    'nowVal': 9980,
#    'risefall': '5',
#    'changeVal': -65,
#    'changeRate': -0.65,
#    'nav': 10005.0,
#    'threeMonthEarnRate': -13.9246,
#    'quant': 212997,
#    'amonut': 2131,
#    'marketSum': 6337},
#   {'itemcode': '152100',
#    'etfTabCode': 1,
#    'itemname': 'ARIRANG 200',
#    'nowVal': 31240,
#    'risefall': '5',
#    'changeVal': -110,
#    'changeRate': -0.35,
#    'nav': 31241.0,
#    'threeMonthEarnRate': -14.5544,
#    'quant': 249560,
#    'amonut': 7792,
#    'marketSum': 5998},
#   {'itemcode': '293180',
#    'etfTabCode': 1,
#    'itemname': 'HANARO 200',
#    'nowVal': 30870,
#    'risefall': '5',
#    'changeVal': -90,
#    'changeRate': -0.29,
#    'nav': 30840.0,
#    'threeMonthEarnRate': -14.4161,
#    'quant': 42298,
#    'amonut': 1306,
#    'marketSum': 5804},
#   {'itemcode': '357870',
#    'etfTabCode': 7,
#    'itemname': 'TIGER CD금리투자KIS(합성)',
#    'nowVal': 50925,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.02,
#    'nav': 50929.0,
#    'threeMonthEarnRate': 0.4141,
#    'quant': 14,
#    'amonut': 0,
#    'marketSum': 5615},
#   {'itemcode': '272580',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 단기채권액티브',
#    'nowVal': 50520,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.01,
#    'nav': 50525.0,
#    'threeMonthEarnRate': 0.1784,
#    'quant': 2417,
#    'amonut': 122,
#    'marketSum': 5396},
#   {'itemcode': '229200',
#    'etfTabCode': 1,
#    'itemname': 'KODEX 코스닥150',
#    'nowVal': 10350,
#    'risefall': '5',
#    'changeVal': -265,
#    'changeRate': -2.5,
#    'nav': 10460.0,
#    'threeMonthEarnRate': -17.4316,
#    'quant': 12757944,
#    'amonut': 134325,
#    'marketSum': 5387},
#   {'itemcode': '360200',
#    'etfTabCode': 4,
#    'itemname': 'KINDEX 미국S&P500',
#    'nowVal': 12400,
#    'risefall': '2',
#    'changeVal': 180,
#    'changeRate': 1.47,
#    'nav': 12410.0,
#    'threeMonthEarnRate': -10.894,
#    'quant': 62056,
#    'amonut': 767,
#    'marketSum': 5258},
#   {'itemcode': '196230',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 단기통안채',
#    'nowVal': 105235,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.01,
#    'nav': 105236.0,
#    'threeMonthEarnRate': 0.157,
#    'quant': 5536,
#    'amonut': 582,
#    'marketSum': 5190},
#   {'itemcode': '294400',
#    'etfTabCode': 1,
#    'itemname': 'KOSEF 200TR',
#    'nowVal': 37290,
#    'risefall': '5',
#    'changeVal': -105,
#    'changeRate': -0.28,
#    'nav': 37248.0,
#    'threeMonthEarnRate': -14.4084,
#    'quant': 4110,
#    'amonut': 153,
#    'marketSum': 5034},
#   {'itemcode': '105190',
#    'etfTabCode': 1,
#    'itemname': 'KINDEX 200',
#    'nowVal': 30865,
#    'risefall': '5',
#    'changeVal': -95,
#    'changeRate': -0.31,
#    'nav': 30845.0,
#    'threeMonthEarnRate': -14.4988,
#    'quant': 272255,
#    'amonut': 8403,
#    'marketSum': 4830},
#   {'itemcode': '190620',
#    'etfTabCode': 6,
#    'itemname': 'KINDEX 단기통안채',
#    'nowVal': 100585,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.01,
#    'nav': 100579.0,
#    'threeMonthEarnRate': 0.2242,
#    'quant': 859,
#    'amonut': 86,
#    'marketSum': 4334},
#   {'itemcode': '251350',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 선진국MSCI World',
#    'nowVal': 18890,
#    'risefall': '2',
#    'changeVal': 370,
#    'changeRate': 2.0,
#    'nav': 18843.0,
#    'threeMonthEarnRate': -11.578,
#    'quant': 15888,
#    'amonut': 299,
#    'marketSum': 4297},
#   {'itemcode': '364980',
#    'etfTabCode': 2,
#    'itemname': 'TIGER KRX2차전지K-뉴딜',
#    'nowVal': 13505,
#    'risefall': '5',
#    'changeVal': -235,
#    'changeRate': -1.71,
#    'nav': 13523.0,
#    'threeMonthEarnRate': 4.4311,
#    'quant': 1272123,
#    'amonut': 17353,
#    'marketSum': 4193},
#   {'itemcode': '315930',
#    'etfTabCode': 2,
#    'itemname': 'KODEX Top5PlusTR',
#    'nowVal': 14830,
#    'risefall': '5',
#    'changeVal': -65,
#    'changeRate': -0.44,
#    'nav': 14848.0,
#    'threeMonthEarnRate': -17.6162,
#    'quant': 13205,
#    'amonut': 195,
#    'marketSum': 4078},
#   {'itemcode': '379800',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국S&P500TR',
#    'nowVal': 10845,
#    'risefall': '2',
#    'changeVal': 160,
#    'changeRate': 1.5,
#    'nav': 10854.0,
#    'threeMonthEarnRate': -10.9955,
#    'quant': 98606,
#    'amonut': 1066,
#    'marketSum': 4072},
#   {'itemcode': '371160',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 차이나항셍테크',
#    'nowVal': 6690,
#    'risefall': '2',
#    'changeVal': 150,
#    'changeRate': 2.29,
#    'nav': 6697.0,
#    'threeMonthEarnRate': 7.1253,
#    'quant': 1065144,
#    'amonut': 7049,
#    'marketSum': 4027},
#   {'itemcode': '385550',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#    'nowVal': 100825,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': 0.0,
#    'nav': 100833.0,
#    'threeMonthEarnRate': 0.1141,
#    'quant': 85416,
#    'amonut': 8613,
#    'marketSum': 3992},
#   {'itemcode': '385540',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#    'nowVal': 93495,
#    'risefall': '2',
#    'changeVal': 225,
#    'changeRate': 0.24,
#    'nav': 93501.0,
#    'threeMonthEarnRate': -4.4218,
#    'quant': 3,
#    'amonut': 0,
#    'marketSum': 3895},
#   {'itemcode': '314250',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국FANG플러스(H)',
#    'nowVal': 19370,
#    'risefall': '2',
#    'changeVal': 350,
#    'changeRate': 1.84,
#    'nav': 19280.0,
#    'threeMonthEarnRate': -24.6285,
#    'quant': 43584,
#    'amonut': 838,
#    'marketSum': 3783},
#   {'itemcode': '367380',
#    'etfTabCode': 4,
#    'itemname': 'KINDEX 미국나스닥100',
#    'nowVal': 11535,
#    'risefall': '2',
#    'changeVal': 170,
#    'changeRate': 1.5,
#    'nav': 11534.0,
#    'threeMonthEarnRate': -15.3067,
#    'quant': 94463,
#    'amonut': 1086,
#    'marketSum': 3749},
#   {'itemcode': '251340',
#    'etfTabCode': 3,
#    'itemname': 'KODEX 코스닥150선물인버스',
#    'nowVal': 5445,
#    'risefall': '2',
#    'changeVal': 140,
#    'changeRate': 2.64,
#    'nav': 5449.0,
#    'threeMonthEarnRate': 18.2831,
#    'quant': 123000503,
#    'amonut': 658240,
#    'marketSum': 3719},
#   {'itemcode': '069660',
#    'etfTabCode': 1,
#    'itemname': 'KOSEF 200',
#    'nowVal': 30740,
#    'risefall': '5',
#    'changeVal': -105,
#    'changeRate': -0.34,
#    'nav': 30725.0,
#    'threeMonthEarnRate': -14.5379,
#    'quant': 320107,
#    'amonut': 9839,
#    'marketSum': 3673},
#   {'itemcode': '148070',
#    'etfTabCode': 6,
#    'itemname': 'KOSEF 국고채10년',
#    'nowVal': 107820,
#    'risefall': '2',
#    'changeVal': 365,
#    'changeRate': 0.34,
#    'nav': 107900.0,
#    'threeMonthEarnRate': -6.3124,
#    'quant': 5045,
#    'amonut': 545,
#    'marketSum': 3655},
#   {'itemcode': '329750',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 미국달러단기채권액티브',
#    'nowVal': 11105,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.27,
#    'nav': 11102.0,
#    'threeMonthEarnRate': 6.5928,
#    'quant': 155155,
#    'amonut': 1721,
#    'marketSum': 3337},
#   {'itemcode': '379810',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국나스닥100TR',
#    'nowVal': 9890,
#    'risefall': '2',
#    'changeVal': 160,
#    'changeRate': 1.64,
#    'nav': 9885.0,
#    'threeMonthEarnRate': -15.3914,
#    'quant': 106834,
#    'amonut': 1051,
#    'marketSum': 3274},
#   {'itemcode': '226490',
#    'etfTabCode': 1,
#    'itemname': 'KODEX 코스피',
#    'nowVal': 23530,
#    'risefall': '5',
#    'changeVal': -190,
#    'changeRate': -0.8,
#    'nav': 23569.0,
#    'threeMonthEarnRate': -13.2724,
#    'quant': 119165,
#    'amonut': 2816,
#    'marketSum': 2824},
#   {'itemcode': '400970',
#    'etfTabCode': 2,
#    'itemname': 'TIGER Fn메타버스',
#    'nowVal': 7615,
#    'risefall': '5',
#    'changeVal': -175,
#    'changeRate': -2.25,
#    'nav': 7635.0,
#    'threeMonthEarnRate': -32.2432,
#    'quant': 1102582,
#    'amonut': 8504,
#    'marketSum': 2749},
#   {'itemcode': '401470',
#    'etfTabCode': 2,
#    'itemname': 'KODEX K-메타버스액티브',
#    'nowVal': 7660,
#    'risefall': '5',
#    'changeVal': -155,
#    'changeRate': -1.98,
#    'nav': 7684.0,
#    'threeMonthEarnRate': -29.9606,
#    'quant': 1060762,
#    'amonut': 8227,
#    'marketSum': 2738},
#   {'itemcode': '217770',
#    'etfTabCode': 5,
#    'itemname': 'TIGER 원유선물인버스(H)',
#    'nowVal': 2980,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.68,
#    'nav': 2987.0,
#    'threeMonthEarnRate': -3.268,
#    'quant': 3790805,
#    'amonut': 11364,
#    'marketSum': 2669},
#   {'itemcode': '367770',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR Fn수소경제테마',
#    'nowVal': 8940,
#    'risefall': '5',
#    'changeVal': -115,
#    'changeRate': -1.27,
#    'nav': 8950.0,
#    'threeMonthEarnRate': -10.0438,
#    'quant': 108739,
#    'amonut': 974,
#    'marketSum': 2593},
#   {'itemcode': '414780',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 차이나과창판STAR50(합성)',
#    'nowVal': 8275,
#    'risefall': '2',
#    'changeVal': 25,
#    'changeRate': 0.3,
#    'nav': 8457.0,
#    'threeMonthEarnRate': -4.8443,
#    'quant': 38423,
#    'amonut': 315,
#    'marketSum': 2549},
#   {'itemcode': '143850',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국S&P500선물(H)',
#    'nowVal': 44110,
#    'risefall': '2',
#    'changeVal': 500,
#    'changeRate': 1.15,
#    'nav': 44113.0,
#    'threeMonthEarnRate': -16.5439,
#    'quant': 24836,
#    'amonut': 1091,
#    'marketSum': 2536},
#   {'itemcode': '329200',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 리츠부동산인프라',
#    'nowVal': 5620,
#    'risefall': '5',
#    'changeVal': -80,
#    'changeRate': -1.4,
#    'nav': 5616.0,
#    'threeMonthEarnRate': -5.2842,
#    'quant': 774942,
#    'amonut': 4351,
#    'marketSum': 2526},
#   {'itemcode': '332940',
#    'etfTabCode': 1,
#    'itemname': 'HANARO MSCI Korea TR',
#    'nowVal': 12530,
#    'risefall': '5',
#    'changeVal': -80,
#    'changeRate': -0.63,
#    'nav': 12547.0,
#    'threeMonthEarnRate': -14.1009,
#    'quant': 51,
#    'amonut': 0,
#    'marketSum': 2519},
#   {'itemcode': '271050',
#    'etfTabCode': 5,
#    'itemname': 'KODEX WTI원유선물인버스(H)',
#    'nowVal': 4285,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.71,
#    'nav': 4285.0,
#    'threeMonthEarnRate': -2.7429,
#    'quant': 7024925,
#    'amonut': 30235,
#    'marketSum': 2481},
#   {'itemcode': '290130',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR ESG사회책임투자',
#    'nowVal': 10220,
#    'risefall': '5',
#    'changeVal': -95,
#    'changeRate': -0.92,
#    'nav': 10229.0,
#    'threeMonthEarnRate': -15.2216,
#    'quant': 76650,
#    'amonut': 781,
#    'marketSum': 2397},
#   {'itemcode': '213610',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 삼성그룹밸류',
#    'nowVal': 7915,
#    'risefall': '5',
#    'changeVal': -35,
#    'changeRate': -0.44,
#    'nav': 7922.0,
#    'threeMonthEarnRate': -7.4721,
#    'quant': 54054,
#    'amonut': 429,
#    'marketSum': 2375},
#   {'itemcode': '364960',
#    'etfTabCode': 2,
#    'itemname': 'TIGER KRX BBIG K-뉴딜',
#    'nowVal': 7550,
#    'risefall': '2',
#    'changeVal': 40,
#    'changeRate': 0.53,
#    'nav': 7559.0,
#    'threeMonthEarnRate': -17.4726,
#    'quant': 532989,
#    'amonut': 4040,
#    'marketSum': 2322},
#   {'itemcode': '394660',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#    'nowVal': 9315,
#    'risefall': '2',
#    'changeVal': 95,
#    'changeRate': 1.03,
#    'nav': 9335.0,
#    'threeMonthEarnRate': -12.1905,
#    'quant': 51751,
#    'amonut': 480,
#    'marketSum': 2299},
#   {'itemcode': '397410',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 국채선물5년추종인버스',
#    'nowVal': 53975,
#    'risefall': '5',
#    'changeVal': -130,
#    'changeRate': -0.24,
#    'nav': 54012.0,
#    'threeMonthEarnRate': 4.1983,
#    'quant': 57,
#    'amonut': 3,
#    'marketSum': 2209},
#   {'itemcode': '379780',
#    'etfTabCode': 4,
#    'itemname': 'KBSTAR 미국S&P500',
#    'nowVal': 10715,
#    'risefall': '2',
#    'changeVal': 145,
#    'changeRate': 1.37,
#    'nav': 10723.0,
#    'threeMonthEarnRate': -10.8769,
#    'quant': 27727,
#    'amonut': 296,
#    'marketSum': 2164},
#   {'itemcode': '368590',
#    'etfTabCode': 4,
#    'itemname': 'KBSTAR 미국나스닥100',
#    'nowVal': 11200,
#    'risefall': '2',
#    'changeVal': 180,
#    'changeRate': 1.63,
#    'nav': 11187.0,
#    'threeMonthEarnRate': -15.387,
#    'quant': 90794,
#    'amonut': 1010,
#    'marketSum': 2128},
#   {'itemcode': '192090',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 차이나CSI300',
#    'nowVal': 11025,
#    'risefall': '2',
#    'changeVal': 135,
#    'changeRate': 1.24,
#    'nav': 11038.0,
#    'threeMonthEarnRate': 2.0618,
#    'quant': 77010,
#    'amonut': 839,
#    'marketSum': 2062},
#   {'itemcode': '091170',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 은행',
#    'nowVal': 6385,
#    'risefall': '5',
#    'changeVal': -80,
#    'changeRate': -1.24,
#    'nav': 6385.0,
#    'threeMonthEarnRate': -14.4389,
#    'quant': 1440069,
#    'amonut': 9284,
#    'marketSum': 2002},
#   {'itemcode': '168580',
#    'etfTabCode': 4,
#    'itemname': 'KINDEX 중국본토CSI300',
#    'nowVal': 29935,
#    'risefall': '2',
#    'changeVal': 760,
#    'changeRate': 2.6,
#    'nav': 29729.0,
#    'threeMonthEarnRate': 1.7791,
#    'quant': 9727,
#    'amonut': 289,
#    'marketSum': 1976},
#   {'itemcode': '091160',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 반도체',
#    'nowVal': 27130,
#    'risefall': '5',
#    'changeVal': -1800,
#    'changeRate': -6.22,
#    'nav': 27148.0,
#    'threeMonthEarnRate': -19.979,
#    'quant': 594762,
#    'amonut': 16275,
#    'marketSum': 1953},
#   {'itemcode': '132030',
#    'etfTabCode': 5,
#    'itemname': 'KODEX 골드선물(H)',
#    'nowVal': 12290,
#    'risefall': '2',
#    'changeVal': 35,
#    'changeRate': 0.29,
#    'nav': 12303.0,
#    'threeMonthEarnRate': -6.4147,
#    'quant': 56259,
#    'amonut': 692,
#    'marketSum': 1942},
#   {'itemcode': '228800',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 여행레저',
#    'nowVal': 3825,
#    'risefall': '5',
#    'changeVal': -145,
#    'changeRate': -3.65,
#    'nav': 3832.0,
#    'threeMonthEarnRate': -22.2332,
#    'quant': 670735,
#    'amonut': 2612,
#    'marketSum': 1799},
#   {'itemcode': '182480',
#    'etfTabCode': 7,
#    'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#    'nowVal': 12720,
#    'risefall': '2',
#    'changeVal': 225,
#    'changeRate': 1.8,
#    'nav': 12827.0,
#    'threeMonthEarnRate': -18.408,
#    'quant': 62856,
#    'amonut': 800,
#    'marketSum': 1685},
#   {'itemcode': '325020',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 배당가치',
#    'nowVal': 11150,
#    'risefall': '5',
#    'changeVal': -95,
#    'changeRate': -0.84,
#    'nav': 11143.0,
#    'threeMonthEarnRate': -10.9378,
#    'quant': 2391,
#    'amonut': 26,
#    'marketSum': 1684},
#   {'itemcode': '412770',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 글로벌메타버스액티브',
#    'nowVal': 6480,
#    'risefall': '2',
#    'changeVal': 65,
#    'changeRate': 1.01,
#    'nav': 6513.0,
#    'threeMonthEarnRate': -24.2622,
#    'quant': 75026,
#    'amonut': 485,
#    'marketSum': 1642},
#   {'itemcode': '245710',
#    'etfTabCode': 4,
#    'itemname': 'KINDEX 베트남VN30(합성)',
#    'nowVal': 19760,
#    'risefall': '5',
#    'changeVal': -50,
#    'changeRate': -0.25,
#    'nav': 19938.0,
#    'threeMonthEarnRate': -15.1606,
#    'quant': 17594,
#    'amonut': 348,
#    'marketSum': 1640},
#   {'itemcode': '275980',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#    'nowVal': 14015,
#    'risefall': '2',
#    'changeVal': 205,
#    'changeRate': 1.48,
#    'nav': 14053.0,
#    'threeMonthEarnRate': -19.0979,
#    'quant': 9191,
#    'amonut': 128,
#    'marketSum': 1626},
#   {'itemcode': '302450',
#    'etfTabCode': 1,
#    'itemname': 'KBSTAR 코스피',
#    'nowVal': 23710,
#    'risefall': '5',
#    'changeVal': -165,
#    'changeRate': -0.69,
#    'nav': 23737.0,
#    'threeMonthEarnRate': -13.5372,
#    'quant': 1849,
#    'amonut': 43,
#    'marketSum': 1589},
#   {'itemcode': '372330',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 차이나항셍테크',
#    'nowVal': 6715,
#    'risefall': '2',
#    'changeVal': 125,
#    'changeRate': 1.9,
#    'nav': 6712.0,
#    'threeMonthEarnRate': 7.6797,
#    'quant': 196378,
#    'amonut': 1302,
#    'marketSum': 1578},
#   {'itemcode': '401170',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR iSelect메타버스',
#    'nowVal': 6915,
#    'risefall': '5',
#    'changeVal': -130,
#    'changeRate': -1.85,
#    'nav': 6901.0,
#    'threeMonthEarnRate': -33.4436,
#    'quant': 142511,
#    'amonut': 992,
#    'marketSum': 1514},
#   {'itemcode': '329650',
#    'etfTabCode': 7,
#    'itemname': 'KODEX TRF3070',
#    'nowVal': 10550,
#    'risefall': '2',
#    'changeVal': 35,
#    'changeRate': 0.33,
#    'nav': 10554.0,
#    'threeMonthEarnRate': -7.1524,
#    'quant': 17417,
#    'amonut': 183,
#    'marketSum': 1509},
#   {'itemcode': '130730',
#    'etfTabCode': 6,
#    'itemname': 'KOSEF 단기자금',
#    'nowVal': 101340,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.01,
#    'nav': 101339.0,
#    'threeMonthEarnRate': 0.1185,
#    'quant': 2873,
#    'amonut': 291,
#    'marketSum': 1480},
#   {'itemcode': '326240',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR IT플러스',
#    'nowVal': 15545,
#    'risefall': '5',
#    'changeVal': -110,
#    'changeRate': -0.7,
#    'nav': 15567.0,
#    'threeMonthEarnRate': -19.9765,
#    'quant': 10743,
#    'amonut': 167,
#    'marketSum': 1467},
#   {'itemcode': '407310',
#    'etfTabCode': 1,
#    'itemname': 'HANARO 200 TOP10',
#    'nowVal': 7570,
#    'risefall': '2',
#    'changeVal': 40,
#    'changeRate': 0.53,
#    'nav': 7588.0,
#    'threeMonthEarnRate': -10.9193,
#    'quant': 57,
#    'amonut': 0,
#    'marketSum': 1461},
#   {'itemcode': '409820',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국나스닥100레버리지(합성 H)',
#    'nowVal': 4640,
#    'risefall': '2',
#    'changeVal': 120,
#    'changeRate': 2.65,
#    'nav': 4637.0,
#    'threeMonthEarnRate': -39.4913,
#    'quant': 1062129,
#    'amonut': 4898,
#    'marketSum': 1457},
#   {'itemcode': '390950',
#    'etfTabCode': 6,
#    'itemname': 'HANARO 단기채권액티브',
#    'nowVal': 100755,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.01,
#    'nav': 100759.0,
#    'threeMonthEarnRate': 0.2039,
#    'quant': 372766,
#    'amonut': 37567,
#    'marketSum': 1451},
#   {'itemcode': '282000',
#    'etfTabCode': 3,
#    'itemname': 'KBSTAR 국고채3년선물인버스',
#    'nowVal': 104805,
#    'risefall': '5',
#    'changeVal': -45,
#    'changeRate': -0.04,
#    'nav': 104805.0,
#    'threeMonthEarnRate': 2.9556,
#    'quant': 31,
#    'amonut': 3,
#    'marketSum': 1431},
#   {'itemcode': '161510',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG 고배당주',
#    'nowVal': 11150,
#    'risefall': '5',
#    'changeVal': -150,
#    'changeRate': -1.33,
#    'nav': 11153.0,
#    'threeMonthEarnRate': -8.1898,
#    'quant': 103321,
#    'amonut': 1156,
#    'marketSum': 1428},
#   {'itemcode': '143860',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 헬스케어',
#    'nowVal': 27100,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.02,
#    'nav': 27299.0,
#    'threeMonthEarnRate': -14.9781,
#    'quant': 103279,
#    'amonut': 2825,
#    'marketSum': 1382},
#   {'itemcode': '219480',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국S&P500선물(H)',
#    'nowVal': 18075,
#    'risefall': '2',
#    'changeVal': 210,
#    'changeRate': 1.18,
#    'nav': 18088.0,
#    'threeMonthEarnRate': -16.9843,
#    'quant': 20859,
#    'amonut': 376,
#    'marketSum': 1292},
#   {'itemcode': '252710',
#    'etfTabCode': 3,
#    'itemname': 'TIGER 200선물인버스2X',
#    'nowVal': 3515,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.57,
#    'nav': 3516.0,
#    'threeMonthEarnRate': 34.423,
#    'quant': 14511455,
#    'amonut': 50765,
#    'marketSum': 1265},
#   {'itemcode': '138540',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 현대차그룹+펀더멘털',
#    'nowVal': 20815,
#    'risefall': '5',
#    'changeVal': -105,
#    'changeRate': -0.5,
#    'nav': 20825.0,
#    'threeMonthEarnRate': -3.5412,
#    'quant': 12994,
#    'amonut': 271,
#    'marketSum': 1232},
#   {'itemcode': '328370',
#    'etfTabCode': 1,
#    'itemname': 'ARIRANG 코스피TR',
#    'nowVal': 11980,
#    'risefall': '5',
#    'changeVal': -90,
#    'changeRate': -0.75,
#    'nav': 12016.0,
#    'threeMonthEarnRate': -13.4457,
#    'quant': 956,
#    'amonut': 11,
#    'marketSum': 1228},
#   {'itemcode': '283580',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 차이나CSI300',
#    'nowVal': 13560,
#    'risefall': '2',
#    'changeVal': 230,
#    'changeRate': 1.73,
#    'nav': 13493.0,
#    'threeMonthEarnRate': 2.1455,
#    'quant': 144794,
#    'amonut': 1936,
#    'marketSum': 1220},
#   {'itemcode': '295040',
#    'etfTabCode': 1,
#    'itemname': 'SOL 200TR',
#    'nowVal': 10685,
#    'risefall': '5',
#    'changeVal': -40,
#    'changeRate': -0.37,
#    'nav': 10660.0,
#    'threeMonthEarnRate': -14.2686,
#    'quant': 16853,
#    'amonut': 180,
#    'marketSum': 1218},
#   {'itemcode': '232080',
#    'etfTabCode': 1,
#    'itemname': 'TIGER 코스닥150',
#    'nowVal': 10635,
#    'risefall': '5',
#    'changeVal': -265,
#    'changeRate': -2.43,
#    'nav': 10707.0,
#    'threeMonthEarnRate': -17.3554,
#    'quant': 311198,
#    'amonut': 3327,
#    'marketSum': 1215},
#   {'itemcode': '415340',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 차이나과창판STAR50(합성)',
#    'nowVal': 8355,
#    'risefall': '2',
#    'changeVal': 110,
#    'changeRate': 1.33,
#    'nav': 8596.0,
#    'threeMonthEarnRate': -6.0399,
#    'quant': 6039,
#    'amonut': 50,
#    'marketSum': 1170},
#   {'itemcode': '363570',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#    'nowVal': 85225,
#    'risefall': '2',
#    'changeVal': 820,
#    'changeRate': 0.97,
#    'nav': 84943.0,
#    'threeMonthEarnRate': -7.9654,
#    'quant': 362,
#    'amonut': 30,
#    'marketSum': 1157},
#   {'itemcode': '273140',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 단기변동금리부채권액티브',
#    'nowVal': 103595,
#    'risefall': '5',
#    'changeVal': -15,
#    'changeRate': -0.01,
#    'nav': 103597.0,
#    'threeMonthEarnRate': 0.3146,
#    'quant': 406,
#    'amonut': 42,
#    'marketSum': 1148},
#   {'itemcode': '309230',
#    'etfTabCode': 4,
#    'itemname': 'KINDEX 미국WideMoat가치주',
#    'nowVal': 16530,
#    'risefall': '2',
#    'changeVal': 215,
#    'changeRate': 1.32,
#    'nav': 16628.0,
#    'threeMonthEarnRate': -9.9614,
#    'quant': 10735,
#    'amonut': 177,
#    'marketSum': 1141},
#   {'itemcode': '091230',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 반도체',
#    'nowVal': 27815,
#    'risefall': '5',
#    'changeVal': -85,
#    'changeRate': -0.3,
#    'nav': 27820.0,
#    'threeMonthEarnRate': -24.6842,
#    'quant': 191958,
#    'amonut': 5370,
#    'marketSum': 1140},
#   {'itemcode': '363510',
#    'etfTabCode': 6,
#    'itemname': 'SOL KIS단기통안채',
#    'nowVal': 100980,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 101011.0,
#    'threeMonthEarnRate': 0.1636,
#    'quant': 0,
#    'amonut': 0,
#    'marketSum': 1134},
#   {'itemcode': '114260',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 국고채3년',
#    'nowVal': 55685,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.05,
#    'nav': 55721.0,
#    'threeMonthEarnRate': -2.488,
#    'quant': 14924,
#    'amonut': 831,
#    'marketSum': 1125},
#   {'itemcode': '204480',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#    'nowVal': 26355,
#    'risefall': '2',
#    'changeVal': 950,
#    'changeRate': 3.74,
#    'nav': 26639.0,
#    'threeMonthEarnRate': -0.7618,
#    'quant': 221114,
#    'amonut': 5786,
#    'marketSum': 1123},
#   {'itemcode': '332930',
#    'etfTabCode': 1,
#    'itemname': 'HANARO 200TR',
#    'nowVal': 37355,
#    'risefall': '5',
#    'changeVal': -85,
#    'changeRate': -0.23,
#    'nav': 37283.0,
#    'threeMonthEarnRate': -14.4425,
#    'quant': 29128,
#    'amonut': 1088,
#    'marketSum': 1121},
#   {'itemcode': '411420',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국메타버스나스닥액티브',
#    'nowVal': 6460,
#    'risefall': '2',
#    'changeVal': 95,
#    'changeRate': 1.49,
#    'nav': 6477.0,
#    'threeMonthEarnRate': -23.1281,
#    'quant': 219583,
#    'amonut': 1413,
#    'marketSum': 1118},
#   {'itemcode': '270810',
#    'etfTabCode': 1,
#    'itemname': 'KBSTAR 코스닥150',
#    'nowVal': 10335,
#    'risefall': '5',
#    'changeVal': -250,
#    'changeRate': -2.36,
#    'nav': 10393.0,
#    'threeMonthEarnRate': -18.1805,
#    'quant': 68034,
#    'amonut': 718,
#    'marketSum': 1085},
#   {'itemcode': '150460',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 중국소비테마',
#    'nowVal': 6505,
#    'risefall': '5',
#    'changeVal': -70,
#    'changeRate': -1.06,
#    'nav': 6514.0,
#    'threeMonthEarnRate': -13.827,
#    'quant': 51202,
#    'amonut': 339,
#    'marketSum': 1069},
#   {'itemcode': '385560',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR KIS국고채30년Enhanced',
#    'nowVal': 71715,
#    'risefall': '2',
#    'changeVal': 730,
#    'changeRate': 1.03,
#    'nav': 71690.0,
#    'threeMonthEarnRate': -18.879,
#    'quant': 18486,
#    'amonut': 1333,
#    'marketSum': 1069},
#   {'itemcode': '228810',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 미디어컨텐츠',
#    'nowVal': 6150,
#    'risefall': '5',
#    'changeVal': -205,
#    'changeRate': -3.23,
#    'nav': 6159.0,
#    'threeMonthEarnRate': -33.1897,
#    'quant': 241136,
#    'amonut': 1515,
#    'marketSum': 1068},
#   {'itemcode': '245360',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 차이나HSCEI',
#    'nowVal': 10220,
#    'risefall': '2',
#    'changeVal': 180,
#    'changeRate': 1.79,
#    'nav': 10223.0,
#    'threeMonthEarnRate': 6.5251,
#    'quant': 11397,
#    'amonut': 115,
#    'marketSum': 1053},
#   {'itemcode': '261220',
#    'etfTabCode': 5,
#    'itemname': 'KODEX WTI원유선물(H)',
#    'nowVal': 17820,
#    'risefall': '5',
#    'changeVal': -150,
#    'changeRate': -0.83,
#    'nav': 17829.0,
#    'threeMonthEarnRate': -3.0483,
#    'quant': 215798,
#    'amonut': 3826,
#    'marketSum': 1047},
#   {'itemcode': '417630',
#    'etfTabCode': 2,
#    'itemname': 'TIGER KEDI혁신기업ESG30',
#    'nowVal': 8735,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.34,
#    'nav': 8739.0,
#    'threeMonthEarnRate': -16.0964,
#    'quant': 264161,
#    'amonut': 2322,
#    'marketSum': 1013},
#   {'itemcode': '395170',
#    'etfTabCode': 2,
#    'itemname': 'KODEX Fn Top10동일가중',
#    'nowVal': 7070,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.28,
#    'nav': 7073.0,
#    'threeMonthEarnRate': -9.3131,
#    'quant': 1889,
#    'amonut': 13,
#    'marketSum': 990},
#   {'itemcode': '365780',
#    'etfTabCode': 6,
#    'itemname': 'KINDEX 국고채10년',
#    'nowVal': 85705,
#    'risefall': '2',
#    'changeVal': 260,
#    'changeRate': 0.3,
#    'nav': 85794.0,
#    'threeMonthEarnRate': -6.156,
#    'quant': 785,
#    'amonut': 67,
#    'marketSum': 972},
#   {'itemcode': '400570',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 유럽탄소배출권선물ICE(H)',
#    'nowVal': 12950,
#    'risefall': '5',
#    'changeVal': -260,
#    'changeRate': -1.97,
#    'nav': 12968.0,
#    'threeMonthEarnRate': 5.2589,
#    'quant': 47576,
#    'amonut': 615,
#    'marketSum': 939},
#   {'itemcode': '261240',
#    'etfTabCode': 7,
#    'itemname': 'KODEX 미국달러선물',
#    'nowVal': 11505,
#    'risefall': '2',
#    'changeVal': 45,
#    'changeRate': 0.39,
#    'nav': 11505.0,
#    'threeMonthEarnRate': 6.4066,
#    'quant': 102604,
#    'amonut': 1179,
#    'marketSum': 934},
#   {'itemcode': '305080',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 미국채10년선물',
#    'nowVal': 11860,
#    'risefall': '2',
#    'changeVal': 120,
#    'changeRate': 1.02,
#    'nav': 11866.0,
#    'threeMonthEarnRate': 0.5136,
#    'quant': 53469,
#    'amonut': 634,
#    'marketSum': 913},
#   {'itemcode': '419430',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 차이나2차전지MSCI(합성)',
#    'nowVal': 11810,
#    'risefall': '2',
#    'changeVal': 255,
#    'changeRate': 2.21,
#    'nav': 11948.0,
#    'threeMonthEarnRate': 15.4345,
#    'quant': 92367,
#    'amonut': 1077,
#    'marketSum': 909},
#   {'itemcode': '245340',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국다우존스30',
#    'nowVal': 19900,
#    'risefall': '2',
#    'changeVal': 290,
#    'changeRate': 1.48,
#    'nav': 19928.0,
#    'threeMonthEarnRate': -6.9558,
#    'quant': 7078,
#    'amonut': 140,
#    'marketSum': 907},
#   {'itemcode': '304940',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국나스닥100선물(H)',
#    'nowVal': 14575,
#    'risefall': '2',
#    'changeVal': 190,
#    'changeRate': 1.32,
#    'nav': 14546.0,
#    'threeMonthEarnRate': -20.9181,
#    'quant': 45654,
#    'amonut': 662,
#    'marketSum': 896},
#   {'itemcode': '414270',
#    'etfTabCode': 4,
#    'itemname': 'KINDEX G2전기차&자율주행액티브',
#    'nowVal': 9800,
#    'risefall': '2',
#    'changeVal': 155,
#    'changeRate': 1.61,
#    'nav': 9913.0,
#    'threeMonthEarnRate': -3.9821,
#    'quant': 242268,
#    'amonut': 2358,
#    'marketSum': 892},
#   {'itemcode': '367760',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR Fn5G테크',
#    'nowVal': 7490,
#    'risefall': '5',
#    'changeVal': -90,
#    'changeRate': -1.19,
#    'nav': 7481.0,
#    'threeMonthEarnRate': -21.1239,
#    'quant': 11326,
#    'amonut': 85,
#    'marketSum': 835},
#   {'itemcode': '123310',
#    'etfTabCode': 3,
#    'itemname': 'TIGER 인버스',
#    'nowVal': 5615,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.27,
#    'nav': 5615.0,
#    'threeMonthEarnRate': 16.6666,
#    'quant': 1389370,
#    'amonut': 7779,
#    'marketSum': 831},
#   {'itemcode': '278240',
#    'etfTabCode': 3,
#    'itemname': 'KBSTAR 코스닥150선물레버리지',
#    'nowVal': 8175,
#    'risefall': '5',
#    'changeVal': -465,
#    'changeRate': -5.38,
#    'nav': 8165.0,
#    'threeMonthEarnRate': -32.6316,
#    'quant': 30977,
#    'amonut': 258,
#    'marketSum': 826},
#   {'itemcode': '277630',
#    'etfTabCode': 1,
#    'itemname': 'TIGER 코스피',
#    'nowVal': 23910,
#    'risefall': '5',
#    'changeVal': -165,
#    'changeRate': -0.69,
#    'nav': 23909.0,
#    'threeMonthEarnRate': -13.3027,
#    'quant': 7611,
#    'amonut': 182,
#    'marketSum': 825},
#   {'itemcode': '144600',
#    'etfTabCode': 5,
#    'itemname': 'KODEX 은선물(H)',
#    'nowVal': 4325,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.12,
#    'nav': 4321.0,
#    'threeMonthEarnRate': -17.0826,
#    'quant': 91082,
#    'amonut': 392,
#    'marketSum': 822},
#   {'itemcode': '272560',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 단기국공채액티브',
#    'nowVal': 102250,
#    'risefall': '5',
#    'changeVal': -25,
#    'changeRate': -0.02,
#    'nav': 102250.0,
#    'threeMonthEarnRate': -0.3605,
#    'quant': 440,
#    'amonut': 45,
#    'marketSum': 803},
#   {'itemcode': '397420',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 국채선물5년추종',
#    'nowVal': 46715,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.06,
#    'nav': 46730.0,
#    'threeMonthEarnRate': -3.633,
#    'quant': 2,
#    'amonut': 0,
#    'marketSum': 793},
#   {'itemcode': '139220',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 200 건설',
#    'nowVal': 2325,
#    'risefall': '5',
#    'changeVal': -80,
#    'changeRate': -3.33,
#    'nav': 2327.0,
#    'threeMonthEarnRate': -21.6102,
#    'quant': 677644,
#    'amonut': 1596,
#    'marketSum': 786},
#   {'itemcode': '395750',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG ESG가치주액티브',
#    'nowVal': 7355,
#    'risefall': '5',
#    'changeVal': -105,
#    'changeRate': -1.41,
#    'nav': 7388.0,
#    'threeMonthEarnRate': -13.427,
#    'quant': 277,
#    'amonut': 2,
#    'marketSum': 772},
#   {'itemcode': '364970',
#    'etfTabCode': 2,
#    'itemname': 'TIGER KRX바이오K-뉴딜',
#    'nowVal': 6255,
#    'risefall': '2',
#    'changeVal': 85,
#    'changeRate': 1.38,
#    'nav': 6266.0,
#    'threeMonthEarnRate': -13.7063,
#    'quant': 701976,
#    'amonut': 4396,
#    'marketSum': 766},
#   {'itemcode': '298340',
#    'etfTabCode': 6,
#    'itemname': 'ARIRANG 국채선물3년',
#    'nowVal': 51420,
#    'risefall': '2',
#    'changeVal': 35,
#    'changeRate': 0.07,
#    'nav': 51402.0,
#    'threeMonthEarnRate': -2.8823,
#    'quant': 18,
#    'amonut': 0,
#    'marketSum': 753},
#   {'itemcode': '267770',
#    'etfTabCode': 3,
#    'itemname': 'TIGER 200선물레버리지',
#    'nowVal': 10820,
#    'risefall': '5',
#    'changeVal': -35,
#    'changeRate': -0.32,
#    'nav': 10783.0,
#    'threeMonthEarnRate': -27.8258,
#    'quant': 596233,
#    'amonut': 6448,
#    'marketSum': 747},
#   {'itemcode': '337160',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 200ESG',
#    'nowVal': 11275,
#    'risefall': '5',
#    'changeVal': -90,
#    'changeRate': -0.79,
#    'nav': 11317.0,
#    'threeMonthEarnRate': -14.0318,
#    'quant': 289,
#    'amonut': 3,
#    'marketSum': 744},
#   {'itemcode': '139280',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 경기방어',
#    'nowVal': 9170,
#    'risefall': '2',
#    'changeVal': 115,
#    'changeRate': 1.27,
#    'nav': 9183.0,
#    'threeMonthEarnRate': -9.0499,
#    'quant': 3241,
#    'amonut': 29,
#    'marketSum': 732},
#   {'itemcode': '322400',
#    'etfTabCode': 2,
#    'itemname': 'HANARO e커머스',
#    'nowVal': 12760,
#    'risefall': '2',
#    'changeVal': 35,
#    'changeRate': 0.28,
#    'nav': 12771.0,
#    'threeMonthEarnRate': -23.1815,
#    'quant': 7293,
#    'amonut': 93,
#    'marketSum': 721},
#   {'itemcode': '174360',
#    'etfTabCode': 4,
#    'itemname': 'KBSTAR 중국본토대형주CSI100',
#    'nowVal': 20025,
#    'risefall': '2',
#    'changeVal': 205,
#    'changeRate': 1.03,
#    'nav': 20085.0,
#    'threeMonthEarnRate': 2.1649,
#    'quant': 2385,
#    'amonut': 47,
#    'marketSum': 721},
#   {'itemcode': '325010',
#    'etfTabCode': 2,
#    'itemname': 'KODEX Fn성장',
#    'nowVal': 12705,
#    'risefall': '5',
#    'changeVal': -135,
#    'changeRate': -1.05,
#    'nav': 12780.0,
#    'threeMonthEarnRate': -17.2894,
#    'quant': 29,
#    'amonut': 0,
#    'marketSum': 699},
#   {'itemcode': '363580',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 200IT TR',
#    'nowVal': 10100,
#    'risefall': '5',
#    'changeVal': -185,
#    'changeRate': -1.8,
#    'nav': 10231.0,
#    'threeMonthEarnRate': -17.7858,
#    'quant': 564,
#    'amonut': 5,
#    'marketSum': 677},
#   {'itemcode': '195980',
#    'etfTabCode': 4,
#    'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#    'nowVal': 9420,
#    'risefall': '5',
#    'changeVal': -50,
#    'changeRate': -0.53,
#    'nav': 9429.0,
#    'threeMonthEarnRate': -11.3711,
#    'quant': 11661,
#    'amonut': 109,
#    'marketSum': 676},
#   {'itemcode': '139230',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 200 중공업',
#    'nowVal': 2835,
#    'risefall': '5',
#    'changeVal': -50,
#    'changeRate': -1.73,
#    'nav': 2845.0,
#    'threeMonthEarnRate': -9.1339,
#    'quant': 935448,
#    'amonut': 2693,
#    'marketSum': 673},
#   {'itemcode': '114820',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 국채3년',
#    'nowVal': 105055,
#    'risefall': '2',
#    'changeVal': 75,
#    'changeRate': 0.07,
#    'nav': 105081.0,
#    'threeMonthEarnRate': -2.4132,
#    'quant': 437,
#    'amonut': 45,
#    'marketSum': 662},
#   {'itemcode': '402970',
#    'etfTabCode': 4,
#    'itemname': 'KINDEX 미국고배당S&P',
#    'nowVal': 10145,
#    'risefall': '2',
#    'changeVal': 75,
#    'changeRate': 0.74,
#    'nav': 10157.0,
#    'threeMonthEarnRate': -3.8756,
#    'quant': 12882,
#    'amonut': 130,
#    'marketSum': 649},
#   {'itemcode': '396510',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 차이나클린에너지SOLACTIVE',
#    'nowVal': 10180,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.05,
#    'nav': 10241.0,
#    'threeMonthEarnRate': 3.457,
#    'quant': 62955,
#    'amonut': 639,
#    'marketSum': 647},
#   {'itemcode': '152870',
#    'etfTabCode': 1,
#    'itemname': '파워 200',
#    'nowVal': 31200,
#    'risefall': '5',
#    'changeVal': -75,
#    'changeRate': -0.24,
#    'nav': 31190.0,
#    'threeMonthEarnRate': -14.5235,
#    'quant': 104,
#    'amonut': 3,
#    'marketSum': 640},
#   {'itemcode': '298770',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 한국대만IT프리미어',
#    'nowVal': 16390,
#    'risefall': '5',
#    'changeVal': -315,
#    'changeRate': -1.89,
#    'nav': 16329.0,
#    'threeMonthEarnRate': -13.4008,
#    'quant': 2593,
#    'amonut': 42,
#    'marketSum': 639},
#   {'itemcode': '157490',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 소프트웨어',
#    'nowVal': 10125,
#    'risefall': '2',
#    'changeVal': 80,
#    'changeRate': 0.8,
#    'nav': 10137.0,
#    'threeMonthEarnRate': -29.1558,
#    'quant': 64530,
#    'amonut': 651,
#    'marketSum': 638},
#   {'itemcode': '385510',
#    'etfTabCode': 2,
#    'itemname': 'KODEX K-신재생에너지액티브',
#    'nowVal': 9785,
#    'risefall': '5',
#    'changeVal': -290,
#    'changeRate': -2.88,
#    'nav': 9805.0,
#    'threeMonthEarnRate': -4.4118,
#    'quant': 38492,
#    'amonut': 381,
#    'marketSum': 636},
#   {'itemcode': '371470',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#    'nowVal': 7905,
#    'risefall': '2',
#    'changeVal': 60,
#    'changeRate': 0.76,
#    'nav': 7950.0,
#    'threeMonthEarnRate': -4.0367,
#    'quant': 26301,
#    'amonut': 207,
#    'marketSum': 632},
#   {'itemcode': '266160',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 고배당',
#    'nowVal': 10850,
#    'risefall': '5',
#    'changeVal': -80,
#    'changeRate': -0.73,
#    'nav': 10859.0,
#    'threeMonthEarnRate': -11.1744,
#    'quant': 4156,
#    'amonut': 45,
#    'marketSum': 618},
#   {'itemcode': '390390',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국반도체MV',
#    'nowVal': 9190,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.33,
#    'nav': 9261.0,
#    'threeMonthEarnRate': -17.5147,
#    'quant': 35832,
#    'amonut': 329,
#    'marketSum': 616},
#   {'itemcode': '200250',
#    'etfTabCode': 4,
#    'itemname': 'KOSEF 인도Nifty50(합성)',
#    'nowVal': 17100,
#    'risefall': '2',
#    'changeVal': 210,
#    'changeRate': 1.24,
#    'nav': 17230.0,
#    'threeMonthEarnRate': -8.2813,
#    'quant': 11102,
#    'amonut': 187,
#    'marketSum': 599},
#   {'itemcode': '195930',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 유로스탁스50(합성 H)',
#    'nowVal': 11960,
#    'risefall': '2',
#    'changeVal': 60,
#    'changeRate': 0.5,
#    'nav': 12027.0,
#    'threeMonthEarnRate': -9.8485,
#    'quant': 4296,
#    'amonut': 51,
#    'marketSum': 598},
#   {'itemcode': '391600',
#    'etfTabCode': 4,
#    'itemname': 'KINDEX 미국친환경그린테마INDXX',
#    'nowVal': 9490,
#    'risefall': '2',
#    'changeVal': 110,
#    'changeRate': 1.17,
#    'nav': 9573.0,
#    'threeMonthEarnRate': -6.9445,
#    'quant': 2444,
#    'amonut': 23,
#    'marketSum': 598},
#   {'itemcode': '225040',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#    'nowVal': 22555,
#    'risefall': '2',
#    'changeVal': 425,
#    'changeRate': 1.92,
#    'nav': 22593.0,
#    'threeMonthEarnRate': -32.0019,
#    'quant': 12562,
#    'amonut': 281,
#    'marketSum': 595},
#   {'itemcode': '228790',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 화장품',
#    'nowVal': 2060,
#    'risefall': '5',
#    'changeVal': -35,
#    'changeRate': -1.67,
#    'nav': 2064.0,
#    'threeMonthEarnRate': -23.8182,
#    'quant': 1109475,
#    'amonut': 2304,
#    'marketSum': 595},
#   {'itemcode': '117700',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 건설',
#    'nowVal': 2555,
#    'risefall': '5',
#    'changeVal': -95,
#    'changeRate': -3.58,
#    'nav': 2557.0,
#    'threeMonthEarnRate': -23.0323,
#    'quant': 728469,
#    'amonut': 1883,
#    'marketSum': 593},
#   {'itemcode': '302190',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 중장기국채',
#    'nowVal': 47840,
#    'risefall': '2',
#    'changeVal': 85,
#    'changeRate': 0.18,
#    'nav': 47892.0,
#    'threeMonthEarnRate': -4.3466,
#    'quant': 399,
#    'amonut': 19,
#    'marketSum': 584},
#   {'itemcode': '423920',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국필라델피아반도체레버리지(합성)',
#    'nowVal': 7930,
#    'risefall': '2',
#    'changeVal': 135,
#    'changeRate': 1.73,
#    'nav': 7971.0,
#    'threeMonthEarnRate': None,
#    'quant': 42860,
#    'amonut': 337,
#    'marketSum': 578},
#   {'itemcode': '385520',
#    'etfTabCode': 2,
#    'itemname': 'KODEX K-미래차액티브',
#    'nowVal': 8940,
#    'risefall': '5',
#    'changeVal': -160,
#    'changeRate': -1.76,
#    'nav': 8979.0,
#    'threeMonthEarnRate': -10.5476,
#    'quant': 54084,
#    'amonut': 485,
#    'marketSum': 577},
#   {'itemcode': '388280',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR Fn컨택트대표',
#    'nowVal': 7630,
#    'risefall': '5',
#    'changeVal': -115,
#    'changeRate': -1.48,
#    'nav': 7636.0,
#    'threeMonthEarnRate': -17.8075,
#    'quant': 6709,
#    'amonut': 51,
#    'marketSum': 571},
#   {'itemcode': '099140',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 차이나H',
#    'nowVal': 17540,
#    'risefall': '2',
#    'changeVal': 345,
#    'changeRate': 2.01,
#    'nav': 17608.0,
#    'threeMonthEarnRate': 6.011,
#    'quant': 7140,
#    'amonut': 124,
#    'marketSum': 544},
#   {'itemcode': '354350',
#    'etfTabCode': 4,
#    'itemname': 'HANARO 글로벌럭셔리S&P(합성)',
#    'nowVal': 14945,
#    'risefall': '2',
#    'changeVal': 70,
#    'changeRate': 0.47,
#    'nav': 14978.0,
#    'threeMonthEarnRate': -12.8844,
#    'quant': 4747,
#    'amonut': 70,
#    'marketSum': 540},
#   {'itemcode': '256750',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 차이나심천ChiNext(합성)',
#    'nowVal': 12830,
#    'risefall': '2',
#    'changeVal': 280,
#    'changeRate': 2.23,
#    'nav': 12881.0,
#    'threeMonthEarnRate': 1.0873,
#    'quant': 17030,
#    'amonut': 215,
#    'marketSum': 539},
#   {'itemcode': '396500',
#    'etfTabCode': 2,
#    'itemname': 'TIGER Fn반도체TOP10',
#    'nowVal': 7115,
#    'risefall': '5',
#    'changeVal': -55,
#    'changeRate': -0.77,
#    'nav': 7113.0,
#    'threeMonthEarnRate': -23.6585,
#    'quant': 169290,
#    'amonut': 1207,
#    'marketSum': 530},
#   {'itemcode': '204450',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 차이나H레버리지(H)',
#    'nowVal': 3015,
#    'risefall': '2',
#    'changeVal': 85,
#    'changeRate': 2.9,
#    'nav': 3009.0,
#    'threeMonthEarnRate': -3.1405,
#    'quant': 279276,
#    'amonut': 826,
#    'marketSum': 528},
#   {'itemcode': '387270',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 글로벌BBIG액티브',
#    'nowVal': 9680,
#    'risefall': '2',
#    'changeVal': 80,
#    'changeRate': 0.83,
#    'nav': 9722.0,
#    'threeMonthEarnRate': -10.9875,
#    'quant': 11223,
#    'amonut': 108,
#    'marketSum': 527},
#   {'itemcode': '422420',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 2차전지액티브',
#    'nowVal': 9190,
#    'risefall': '5',
#    'changeVal': -345,
#    'changeRate': -3.62,
#    'nav': 9184.0,
#    'threeMonthEarnRate': None,
#    'quant': 386522,
#    'amonut': 3608,
#    'marketSum': 526},
#   {'itemcode': '310960',
#    'etfTabCode': 1,
#    'itemname': 'TIGER 200TR',
#    'nowVal': 16710,
#    'risefall': '5',
#    'changeVal': -55,
#    'changeRate': -0.33,
#    'nav': 16687.0,
#    'threeMonthEarnRate': -14.508,
#    'quant': 3767,
#    'amonut': 62,
#    'marketSum': 518},
#   {'itemcode': '419890',
#    'etfTabCode': 6,
#    'itemname': '히어로즈 단기채권ESG액티브',
#    'nowVal': 99665,
#    'risefall': '2',
#    'changeVal': 35,
#    'changeRate': 0.04,
#    'nav': 99658.0,
#    'threeMonthEarnRate': -0.5739,
#    'quant': 2,
#    'amonut': 0,
#    'marketSum': 498},
#   {'itemcode': '387280',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 퓨처모빌리티액티브',
#    'nowVal': 8810,
#    'risefall': '5',
#    'changeVal': -270,
#    'changeRate': -2.97,
#    'nav': 8765.0,
# ...
#   {'itemcode': '252410',
#    'etfTabCode': 3,
#    'itemname': 'KBSTAR 200선물인버스',
#    'nowVal': 6495,
#    'risefall': '2',
#    'changeVal': 50,
#    'changeRate': 0.78,
#    'nav': 6491.0,
#    'threeMonthEarnRate': 15.2951,
#    'quant': 10782,
#    'amonut': 69,
#    'marketSum': 52},
#   {'itemcode': '301410',
#    'etfTabCode': 3,
#    'itemname': 'ARIRANG 코스닥150선물인버스',
#    'nowVal': 8565,
#    'risefall': '2',
#    'changeVal': 230,
#    'changeRate': 2.76,
#    'nav': 8576.0,
#    'threeMonthEarnRate': 17.0646,
#    'quant': 70336,
#    'amonut': 591,
#    'marketSum': 51},
#   {'itemcode': '215620',
#    'etfTabCode': 2,
#    'itemname': 'HK S&P코리아로우볼',
#    'nowVal': 11385,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 11228.0,
#    'threeMonthEarnRate': -5.2277,
#    'quant': 0,
#    'amonut': 0,
#    'marketSum': 51},
#   {'itemcode': '333940',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG KS로우볼가중TR',
#    'nowVal': 11385,
#    'risefall': '5',
#    'changeVal': -40,
#    'changeRate': -0.35,
#    'nav': 11427.0,
#    'threeMonthEarnRate': -11.7761,
#    'quant': 102,
#    'amonut': 1,
#    'marketSum': 51},
#   {'itemcode': '105010',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 라틴35',
#    'nowVal': 3645,
#    'risefall': '5',
#    'changeVal': -15,
#    'changeRate': -0.41,
#    'nav': 3646.0,
#    'threeMonthEarnRate': -6.6327,
#    'quant': 4034,
#    'amonut': 14,
#    'marketSum': 51},
#   {'itemcode': '261920',
#    'etfTabCode': 4,
#    'itemname': 'KINDEX 필리핀MSCI(합성)',
#    'nowVal': 12710,
#    'risefall': '5',
#    'changeVal': -275,
#    'changeRate': -2.12,
#    'nav': 12639.0,
#    'threeMonthEarnRate': -8.4274,
#    'quant': 807,
#    'amonut': 10,
#    'marketSum': 51},
#   {'itemcode': '140580',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 우량업종',
#    'nowVal': 10075,
#    'risefall': '5',
#    'changeVal': -100,
#    'changeRate': -0.98,
#    'nav': 10065.0,
#    'threeMonthEarnRate': -11.6907,
#    'quant': 31,
#    'amonut': 0,
#    'marketSum': 50},
#   {'itemcode': '295820',
#    'etfTabCode': 1,
#    'itemname': 'ARIRANG 200동일가중',
#    'nowVal': 9120,
#    'risefall': '5',
#    'changeVal': -115,
#    'changeRate': -1.25,
#    'nav': 9152.0,
#    'threeMonthEarnRate': -12.5971,
#    'quant': 130,
#    'amonut': 1,
#    'marketSum': 50},
#   {'itemcode': '285010',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200중공업',
#    'nowVal': 8770,
#    'risefall': '5',
#    'changeVal': -130,
#    'changeRate': -1.46,
#    'nav': 8787.0,
#    'threeMonthEarnRate': -9.1466,
#    'quant': 35984,
#    'amonut': 323,
#    'marketSum': 49},
#   {'itemcode': '267440',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 미국장기국채선물(H)',
#    'nowVal': 9785,
#    'risefall': '2',
#    'changeVal': 125,
#    'changeRate': 1.29,
#    'nav': 9795.0,
#    'threeMonthEarnRate': -10.1814,
#    'quant': 3710,
#    'amonut': 36,
#    'marketSum': 49},
#   {'itemcode': '407300',
#    'etfTabCode': 2,
#    'itemname': 'HANARO Fn골프테마',
#    'nowVal': 6905,
#    'risefall': '5',
#    'changeVal': -160,
#    'changeRate': -2.26,
#    'nav': 6920.0,
#    'threeMonthEarnRate': -19.1093,
#    'quant': 3291,
#    'amonut': 22,
#    'marketSum': 48},
#   {'itemcode': '376250',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG 탄소효율그린뉴딜',
#    'nowVal': 7425,
#    'risefall': '5',
#    'changeVal': -75,
#    'changeRate': -1.0,
#    'nav': 7463.0,
#    'threeMonthEarnRate': -14.8695,
#    'quant': 225,
#    'amonut': 1,
#    'marketSum': 48},
#   {'itemcode': '291890',
#    'etfTabCode': 4,
#    'itemname': 'KODEX MSCI EM선물(H)',
#    'nowVal': 7970,
#    'risefall': '5',
#    'changeVal': -70,
#    'changeRate': -0.87,
#    'nav': 8022.0,
#    'threeMonthEarnRate': -10.9635,
#    'quant': 15,
#    'amonut': 0,
#    'marketSum': 48},
#   {'itemcode': '334690',
#    'etfTabCode': 5,
#    'itemname': 'KBSTAR 팔라듐선물(H)',
#    'nowVal': 10560,
#    'risefall': '2',
#    'changeVal': 125,
#    'changeRate': 1.2,
#    'nav': 10605.0,
#    'threeMonthEarnRate': -29.6596,
#    'quant': 4008,
#    'amonut': 41,
#    'marketSum': 48},
#   {'itemcode': '346000',
#    'etfTabCode': 6,
#    'itemname': 'HANARO KAP초장기국고채',
#    'nowVal': 37425,
#    'risefall': '2',
#    'changeVal': 90,
#    'changeRate': 0.24,
#    'nav': 37429.0,
#    'threeMonthEarnRate': -9.5129,
#    'quant': 654,
#    'amonut': 24,
#    'marketSum': 47},
#   {'itemcode': '220130',
#    'etfTabCode': 4,
#    'itemname': 'SOL 중국본토 중소형 CSI500(합성 H)',
#    'nowVal': 5200,
#    'risefall': '5',
#    'changeVal': -25,
#    'changeRate': -0.48,
#    'nav': 5210.0,
#    'threeMonthEarnRate': -6.3621,
#    'quant': 1372,
#    'amonut': 7,
#    'marketSum': 47},
#   {'itemcode': '380340',
#    'etfTabCode': 2,
#    'itemname': 'KINDEX Fn5G플러스',
#    'nowVal': 6630,
#    'risefall': '5',
#    'changeVal': -130,
#    'changeRate': -1.92,
#    'nav': 6693.0,
#    'threeMonthEarnRate': -21.1938,
#    'quant': 1361,
#    'amonut': 9,
#    'marketSum': 46},
#   {'itemcode': '275300',
#    'etfTabCode': 2,
#    'itemname': 'KODEX MSCI퀄리티',
#    'nowVal': 7655,
#    'risefall': '5',
#    'changeVal': -10,
#    'changeRate': -0.13,
#    'nav': 7637.0,
#    'threeMonthEarnRate': -14.9468,
#    'quant': 92,
#    'amonut': 0,
#    'marketSum': 46},
#   {'itemcode': '321410',
#    'etfTabCode': 7,
#    'itemname': 'KODEX 멀티에셋하이인컴(H)',
#    'nowVal': 9150,
#    'risefall': '5',
#    'changeVal': -30,
#    'changeRate': -0.33,
#    'nav': 9220.0,
#    'threeMonthEarnRate': -10.7004,
#    'quant': 18,
#    'amonut': 0,
#    'marketSum': 46},
#   {'itemcode': '404470',
#    'etfTabCode': 2,
#    'itemname': 'HANARO KRX기후변화솔루션',
#    'nowVal': 8275,
#    'risefall': '5',
#    'changeVal': -140,
#    'changeRate': -1.66,
#    'nav': 8296.0,
#    'threeMonthEarnRate': -3.9384,
#    'quant': 54,
#    'amonut': 0,
#    'marketSum': 46},
#   {'itemcode': '267490',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 미국장기국채선물레버리지(합성 H)',
#    'nowVal': 9030,
#    'risefall': '2',
#    'changeVal': 275,
#    'changeRate': 3.14,
#    'nav': 9015.0,
#    'threeMonthEarnRate': -20.1551,
#    'quant': 1203,
#    'amonut': 10,
#    'marketSum': 45},
#   {'itemcode': '373490',
#    'etfTabCode': 2,
#    'itemname': 'KODEX K-이노베이션액티브',
#    'nowVal': 8865,
#    'risefall': '5',
#    'changeVal': -145,
#    'changeRate': -1.61,
#    'nav': 8897.0,
#    'threeMonthEarnRate': -14.5729,
#    'quant': 1104,
#    'amonut': 9,
#    'marketSum': 44},
#   {'itemcode': '292340',
#    'etfTabCode': 3,
#    'itemname': '마이티 200커버드콜ATM레버리지',
#    'nowVal': 7380,
#    'risefall': '5',
#    'changeVal': -175,
#    'changeRate': -2.32,
#    'nav': 7378.0,
#    'threeMonthEarnRate': -18.8507,
#    'quant': 3,
#    'amonut': 0,
#    'marketSum': 44},
#   {'itemcode': '139290',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 200 경기소비재',
#    'nowVal': 14450,
#    'risefall': '5',
#    'changeVal': -55,
#    'changeRate': -0.38,
#    'nav': 14513.0,
#    'threeMonthEarnRate': -4.679,
#    'quant': 404,
#    'amonut': 5,
#    'marketSum': 43},
#   {'itemcode': '391680',
#    'etfTabCode': 1,
#    'itemname': 'HK 하이볼액티브',
#    'nowVal': 7180,
#    'risefall': '5',
#    'changeVal': -45,
#    'changeRate': -0.62,
#    'nav': 7168.0,
#    'threeMonthEarnRate': -14.8999,
#    'quant': 31,
#    'amonut': 0,
#    'marketSum': 43},
#   {'itemcode': '281990',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 중소형고배당',
#    'nowVal': 10520,
#    'risefall': '5',
#    'changeVal': -220,
#    'changeRate': -2.05,
#    'nav': 10552.0,
#    'threeMonthEarnRate': -11.1443,
#    'quant': 194,
#    'amonut': 2,
#    'marketSum': 42},
#   {'itemcode': '280940',
#    'etfTabCode': 5,
#    'itemname': 'KODEX 골드선물인버스(H)',
#    'nowVal': 7010,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 7048.0,
#    'threeMonthEarnRate': 5.6518,
#    'quant': 1258,
#    'amonut': 8,
#    'marketSum': 42},
#   {'itemcode': '140570',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 수출주',
#    'nowVal': 10260,
#    'risefall': '5',
#    'changeVal': -150,
#    'changeRate': -1.44,
#    'nav': 10238.0,
#    'threeMonthEarnRate': -10.3437,
#    'quant': 5117,
#    'amonut': 53,
#    'marketSum': 41},
#   {'itemcode': '412560',
#    'etfTabCode': 2,
#    'itemname': 'TIGER KRX BBIG K-뉴딜레버리지',
#    'nowVal': 3880,
#    'risefall': '5',
#    'changeVal': -10,
#    'changeRate': -0.26,
#    'nav': 3897.0,
#    'threeMonthEarnRate': -32.23,
#    'quant': 7943,
#    'amonut': 31,
#    'marketSum': 41},
#   {'itemcode': '267500',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#    'nowVal': 8105,
#    'risefall': '5',
#    'changeVal': -195,
#    'changeRate': -2.35,
#    'nav': 8040.0,
#    'threeMonthEarnRate': 22.2385,
#    'quant': 18960,
#    'amonut': 151,
#    'marketSum': 41},
#   {'itemcode': '275750',
#    'etfTabCode': 3,
#    'itemname': 'KBSTAR 코스닥150선물인버스',
#    'nowVal': 5705,
#    'risefall': '2',
#    'changeVal': 150,
#    'changeRate': 2.7,
#    'nav': 5712.0,
#    'threeMonthEarnRate': 17.6906,
#    'quant': 51328,
#    'amonut': 289,
#    'marketSum': 40},
#   {'itemcode': '314700',
#    'etfTabCode': 2,
#    'itemname': 'HANARO 농업융복합산업',
#    'nowVal': 11315,
#    'risefall': '5',
#    'changeVal': -200,
#    'changeRate': -1.74,
#    'nav': 11342.0,
#    'threeMonthEarnRate': -0.6557,
#    'quant': 8754,
#    'amonut': 98,
#    'marketSum': 40},
#   {'itemcode': '217790',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 가격조정',
#    'nowVal': 19745,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 18930.0,
#    'threeMonthEarnRate': -14.3161,
#    'quant': 0,
#    'amonut': 0,
#    'marketSum': 39},
#   {'itemcode': '301440',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG 코스피중형주',
#    'nowVal': 9840,
#    'risefall': '5',
#    'changeVal': -170,
#    'changeRate': -1.7,
#    'nav': 9870.0,
#    'threeMonthEarnRate': -14.0035,
#    'quant': 114,
#    'amonut': 1,
#    'marketSum': 39},
#   {'itemcode': '244660',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 퀄리티Plus',
#    'nowVal': 7820,
#    'risefall': '5',
#    'changeVal': -140,
#    'changeRate': -1.76,
#    'nav': 7830.0,
#    'threeMonthEarnRate': -18.9245,
#    'quant': 162,
#    'amonut': 1,
#    'marketSum': 39},
#   {'itemcode': '227560',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 200 생활소비재',
#    'nowVal': 8470,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.24,
#    'nav': 8500.0,
#    'threeMonthEarnRate': -9.4417,
#    'quant': 2536,
#    'amonut': 21,
#    'marketSum': 39},
#   {'itemcode': '291630',
#    'etfTabCode': 3,
#    'itemname': 'KOSEF 코스닥150선물레버리지',
#    'nowVal': 3505,
#    'risefall': '5',
#    'changeVal': -190,
#    'changeRate': -5.14,
#    'nav': 3507.0,
#    'threeMonthEarnRate': -33.3634,
#    'quant': 34380,
#    'amonut': 123,
#    'marketSum': 37},
#   {'itemcode': '333960',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG KS모멘텀가중TR',
#    'nowVal': 12345,
#    'risefall': '5',
#    'changeVal': -170,
#    'changeRate': -1.36,
#    'nav': 12380.0,
#    'threeMonthEarnRate': -14.5443,
#    'quant': 16,
#    'amonut': 0,
#    'marketSum': 37},
#   {'itemcode': '306530',
#    'etfTabCode': 3,
#    'itemname': 'HANARO 코스닥150선물레버리지',
#    'nowVal': 7120,
#    'risefall': '5',
#    'changeVal': -325,
#    'changeRate': -4.37,
#    'nav': 7078.0,
#    'threeMonthEarnRate': -32.8069,
#    'quant': 28324,
#    'amonut': 208,
#    'marketSum': 37},
#   {'itemcode': '284980',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200금융',
#    'nowVal': 7750,
#    'risefall': '5',
#    'changeVal': -100,
#    'changeRate': -1.27,
#    'nav': 7760.0,
#    'threeMonthEarnRate': -12.8553,
#    'quant': 1397,
#    'amonut': 11,
#    'marketSum': 36},
#   {'itemcode': '278420',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG ESG우수기업',
#    'nowVal': 7915,
#    'risefall': '5',
#    'changeVal': -110,
#    'changeRate': -1.37,
#    'nav': 7939.0,
#    'threeMonthEarnRate': -9.9529,
#    'quant': 267,
#    'amonut': 2,
#    'marketSum': 36},
#   {'itemcode': '157500',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 증권',
#    'nowVal': 3455,
#    'risefall': '5',
#    'changeVal': -35,
#    'changeRate': -1.0,
#    'nav': 3465.0,
#    'threeMonthEarnRate': -20.2286,
#    'quant': 3412,
#    'amonut': 11,
#    'marketSum': 35},
#   {'itemcode': '266550',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG 중형주저변동50',
#    'nowVal': 9740,
#    'risefall': '5',
#    'changeVal': -125,
#    'changeRate': -1.27,
#    'nav': 9751.0,
#    'threeMonthEarnRate': -10.5865,
#    'quant': 62,
#    'amonut': 0,
#    'marketSum': 34},
#   {'itemcode': '368470',
#    'etfTabCode': 2,
#    'itemname': 'KINDEX Fn K-뉴딜디지털플러스',
#    'nowVal': 10210,
#    'risefall': '2',
#    'changeVal': 100,
#    'changeRate': 0.99,
#    'nav': 10088.0,
#    'threeMonthEarnRate': -11.3858,
#    'quant': 110,
#    'amonut': 1,
#    'marketSum': 31},
#   {'itemcode': '333980',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG KS퀄리티가중TR',
#    'nowVal': 12230,
#    'risefall': '5',
#    'changeVal': -45,
#    'changeRate': -0.37,
#    'nav': 12268.0,
#    'threeMonthEarnRate': -15.2865,
#    'quant': 32,
#    'amonut': 0,
#    'marketSum': 31},
#   {'itemcode': '334700',
#    'etfTabCode': 5,
#    'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#    'nowVal': 4820,
#    'risefall': '5',
#    'changeVal': -35,
#    'changeRate': -0.72,
#    'nav': 4914.0,
#    'threeMonthEarnRate': 26.5971,
#    'quant': 6944,
#    'amonut': 33,
#    'marketSum': 29},
#   {'itemcode': '176710',
#    'etfTabCode': 6,
#    'itemname': '파워 중기국고채',
#    'nowVal': 95595,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 95697.0,
#    'threeMonthEarnRate': -2.5039,
#    'quant': 0,
#    'amonut': 0,
#    'marketSum': 29},
#   {'itemcode': '287300',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200건설',
#    'nowVal': 9455,
#    'risefall': '5',
#    'changeVal': -400,
#    'changeRate': -4.06,
#    'nav': 9466.0,
#    'threeMonthEarnRate': -20.6586,
#    'quant': 1102,
#    'amonut': 10,
#    'marketSum': 28},
#   {'itemcode': '280920',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG 주도업종',
#    'nowVal': 7885,
#    'risefall': '5',
#    'changeVal': -140,
#    'changeRate': -1.74,
#    'nav': 7913.0,
#    'threeMonthEarnRate': -15.4284,
#    'quant': 26,
#    'amonut': 0,
#    'marketSum': 28},
#   {'itemcode': '252730',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 모멘텀로우볼',
#    'nowVal': 13105,
#    'risefall': '5',
#    'changeVal': -165,
#    'changeRate': -1.24,
#    'nav': 13098.0,
#    'threeMonthEarnRate': -13.7696,
#    'quant': 4,
#    'amonut': 0,
#    'marketSum': 26},
#   {'itemcode': '309210',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG KRX300헬스케어',
#    'nowVal': 8405,
#    'risefall': '2',
#    'changeVal': 50,
#    'changeRate': 0.6,
#    'nav': 8476.0,
#    'threeMonthEarnRate': -13.1046,
#    'quant': 105,
#    'amonut': 0,
#    'marketSum': 25},
#   {'itemcode': '301400',
#    'etfTabCode': 1,
#    'itemname': 'ARIRANG 코스닥150',
#    'nowVal': 10455,
#    'risefall': '5',
#    'changeVal': -300,
#    'changeRate': -2.79,
#    'nav': 10551.0,
#    'threeMonthEarnRate': -17.3138,
#    'quant': 4344,
#    'amonut': 45,
#    'marketSum': 21},
#   {'itemcode': '315480',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200커뮤니케이션서비스',
#    'nowVal': 12850,
#    'risefall': '2',
#    'changeVal': 195,
#    'changeRate': 1.54,
#    'nav': 12839.0,
#    'threeMonthEarnRate': -23.126,
#    'quant': 7,
#    'amonut': 0,
#    'marketSum': 18},
#   {'itemcode': '285020',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200철강소재',
#    'nowVal': 7310,
#    'risefall': '5',
#    'changeVal': -215,
#    'changeRate': -2.86,
#    'nav': 7316.0,
#    'threeMonthEarnRate': -14.943,
#    'quant': 4386,
#    'amonut': 32,
#    'marketSum': 18},
#   {'itemcode': '252720',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 모멘텀밸류',
#    'nowVal': 12010,
#    'risefall': '5',
#    'changeVal': -150,
#    'changeRate': -1.23,
#    'nav': 11986.0,
#    'threeMonthEarnRate': -12.1324,
#    'quant': 50,
#    'amonut': 0,
#    'marketSum': 12},
#   {'itemcode': '284990',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200에너지화학',
#    'nowVal': 10650,
#    'risefall': '5',
#    'changeVal': -150,
#    'changeRate': -1.39,
#    'nav': 10633.0,
#    'threeMonthEarnRate': -1.1442,
#    'quant': 586,
#    'amonut': 6,
#    'marketSum': 11},
#   {'itemcode': '287330',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200생활소비재',
#    'nowVal': 6435,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.47,
#    'nav': 6432.0,
#    'threeMonthEarnRate': -9.3675,
#    'quant': 37,
#    'amonut': 0,
#    'marketSum': 9},
#   {'itemcode': '287320',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200산업재',
#    'nowVal': 10740,
#    'risefall': '5',
#    'changeVal': -260,
#    'changeRate': -2.36,
#    'nav': 10756.0,
#    'threeMonthEarnRate': -6.5103,
#    'quant': 243,
#    'amonut': 2,
#    'marketSum': 9},
#   {'itemcode': '287310',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200경기소비재',
#    'nowVal': 9075,
#    'risefall': '5',
#    'changeVal': -20,
#    'changeRate': -0.22,
#    'nav': 9083.0,
#    'threeMonthEarnRate': -4.7046,
#    'quant': 505,
#    'amonut': 4,
#    'marketSum': 7}]}

# %% [markdown]
# ### JSON 타입으로 데이터 받기

# %%
# requests 의 응답을 json 타입으로 받습니다.
# etf_json

# %% [markdown]
# ### JSON 에서 원하는 데이터 찾기

# %%
# result > etfItemList 의 하위 구조로 목록을 찾고자 하는 데이터를 가져옵니다.
etfItemList = etf_json["result"]["etfItemList"]
len(etfItemList)
# Out:
# 575

# %% [markdown]
# ## 데이터프레임 변환
# ### JSON 데이터를 pandas 의 데이터프레임 형태로 만들기

# %%
# 키-값 형태의 데이터를 데이터프레임으로 만듭니다.
df = pd.DataFrame(etfItemList)
df
# Out:
#     itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0     069500           1              KODEX 200   30775        5       -115
# 1     371460           4  TIGER 차이나전기차SOLACTIVE   17510        2        510
# 2     122630           3             KODEX 레버리지   14255        5        -65
# 3     133690           4         TIGER 미국나스닥100   67165        2       1065
# 4     252670           3       KODEX 200선물인버스2X    3360        2         15
# ..       ...         ...                    ...     ...      ...        ...
# 570   252720           2           KBSTAR 모멘텀밸류   12010        5       -150
# 571   284990           2        KBSTAR 200에너지화학   10650        5       -150
# 572   287330           2        KBSTAR 200생활소비재    6435        2         30
# 573   287320           2          KBSTAR 200산업재   10740        5       -260
# 574   287310           2        KBSTAR 200경기소비재    9075        5        -20
#
#      changeRate      nav  threeMonthEarnRate      quant   amonut  marketSum
# 0         -0.37  30761.0            -14.4298    8520894   262842      47455
# 1          3.00  17554.0             12.6573   11623919   201763      41933
# 2         -0.45  14282.0            -28.0583   53123036   760029      22095
# 3          1.61  67140.0            -15.3487     109913     7357      19961
# 4          0.45   3360.0             34.3373  364059617  1216157      19632
# ..          ...      ...                 ...        ...      ...        ...
# 570       -1.23  11986.0            -12.1324         50        0         12
# 571       -1.39  10633.0             -1.1442        586        6         11
# 572        0.47   6432.0             -9.3675         37        0          9
# 573       -2.36  10756.0             -6.5103        243        2          9
# 574       -0.22   9083.0             -4.7046        505        4          7
#
# [575 rows x 12 columns]

# %% [markdown]
# ### 데이터 확인

# %%
# 데이터 프레임으로 잘 만들어 졌는지 상단 데이터의 일부만 미리보기 합니다.

# %%
# 데이터 프레임으로 잘 만들어 졌는지 하단 데이터의 일부만 미리보기 합니다.

# %% [markdown]
# ## 파일 저장
# ### 파일명 만들기

# %%
# 파이썬 표준라이브러리인 datetime을 불러옵니다.
# 날짜를 만들어 저장하기 위해 오늘 날짜를 구합니다.
df.tail()
# Out:
#     itemcode  etfTabCode         itemname  nowVal risefall  changeVal  \
# 570   252720           2     KBSTAR 모멘텀밸류   12010        5       -150
# 571   284990           2  KBSTAR 200에너지화학   10650        5       -150
# 572   287330           2  KBSTAR 200생활소비재    6435        2         30
# 573   287320           2    KBSTAR 200산업재   10740        5       -260
# 574   287310           2  KBSTAR 200경기소비재    9075        5        -20
#
#      changeRate      nav  threeMonthEarnRate  quant  amonut  marketSum
# 570       -1.23  11986.0            -12.1324     50       0         12
# 571       -1.39  10633.0             -1.1442    586       6         11
# 572        0.47   6432.0             -9.3675     37       0          9
# 573       -2.36  10756.0             -6.5103    243       2          9
# 574       -0.22   9083.0             -4.7046    505       4          7

# %%
# f-string 방식으로 파일명을 만들어 줍니다.
# eft_날짜_raw.csv 형태로 만듭니다.
# file_name
import datetime
today = datetime.datetime.today()
today = today.strftime("%Y-%m-%d")

# %% [markdown]
# ### 파일로 저장하고 불러오기

# %%
# csv 형태로 저장합니다. index 가 저장되지 않도록 합니다.
file_name = f"eft_{today}_raw_csv"
file_name
df.to_csv(f"datas/{file_name}", index=False)

# %%
# 저장된 csv 파일을 읽어옵니다.
# itemcode 숫자 앞의 0 이 지워진다면 dtype={"itemcode": np.object} 로 타입을 지정해 주면 문자형태로 읽어옵니다.
pd.read_csv(f"datas/{file_name}", dtype={"itemcode": np.object0})
# Out:
#     itemcode  etfTabCode               itemname  nowVal  risefall  changeVal  \
# 0     069500           1              KODEX 200   30775         5       -115
# 1     371460           4  TIGER 차이나전기차SOLACTIVE   17510         2        510
# 2     122630           3             KODEX 레버리지   14255         5        -65
# 3     133690           4         TIGER 미국나스닥100   67165         2       1065
# 4     252670           3       KODEX 200선물인버스2X    3360         2         15
# ..       ...         ...                    ...     ...       ...        ...
# 570   252720           2           KBSTAR 모멘텀밸류   12010         5       -150
# 571   284990           2        KBSTAR 200에너지화학   10650         5       -150
# 572   287330           2        KBSTAR 200생활소비재    6435         2         30
# 573   287320           2          KBSTAR 200산업재   10740         5       -260
# 574   287310           2        KBSTAR 200경기소비재    9075         5        -20
#
#      changeRate      nav  threeMonthEarnRate      quant   amonut  marketSum
# 0         -0.37  30761.0            -14.4298    8520894   262842      47455
# 1          3.00  17554.0             12.6573   11623919   201763      41933
# 2         -0.45  14282.0            -28.0583   53123036   760029      22095
# 3          1.61  67140.0            -15.3487     109913     7357      19961
# 4          0.45   3360.0             34.3373  364059617  1216157      19632
# ..          ...      ...                 ...        ...      ...        ...
# 570       -1.23  11986.0            -12.1324         50        0         12
# 571       -1.39  10633.0             -1.1442        586        6         11
# 572        0.47   6432.0             -9.3675         37        0          9
# 573       -2.36  10756.0             -6.5103        243        2          9
# 574       -0.22   9083.0             -4.7046        505        4          7
#
# [575 rows x 12 columns]
